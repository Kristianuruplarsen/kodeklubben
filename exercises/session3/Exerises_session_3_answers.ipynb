# %% [markdown]
# # Øvelser til kodeklubben 2.0
# Sidste gang scrapede vi data fra kandidat-testen. Denne gang skal vi visualisere datasættet på en let og overskuelig måde, for at overbevise os om at der er noget information at kommet efter.

# %% [markdown]
# ## Opgave 1 - load data og *final touches*
# ### Opgave 1.1 Indlæs datasættet
# Load data, enten dem i gemte sidste gang, eller fra github (brug koden fra slides)

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/'\
      'Kristianuruplarsen/kodeklubben/master'\
      '/data/candidates.csv?token=AT6RFhI3QPKgojUjNJm0sRVWlOoB7wHMks5b7qukwA%3D%3D'

df = pd.read_csv(url)

# %% [markdown]
# ### Opgave 1.2 - final touches
# Lige nu er kandidaternes svar registreret i en enkelt streng af tal mellem 1 og 5. Et 1-tal svarer til at kandidaten har svaret det mest venstrestille ("Meget uenig"), 5 svarer ligeledes til det meste højrestillede ("Meget enig"). Drop de kandidater der ikke har svaret på alle spørgsmålene fra datasættet. Skriv en funktion der spreder de resterende kandidaters svar ud på 15 variable (en for hvert spørgsmål).

# %%
df
# Out:
#       id      kommune letter                         party  \
# 0      1  albertslund      A             Socialdemokratiet
# 1      1  albertslund      A             Socialdemokratiet
# 2      1  albertslund      A             Socialdemokratiet
# 3      1  albertslund      A             Socialdemokratiet
# 4      1  albertslund      A             Socialdemokratiet
# 5      1  albertslund      A             Socialdemokratiet
# 6      1  albertslund      A             Socialdemokratiet
# 7      1  albertslund      A             Socialdemokratiet
# 8      1  albertslund      A             Socialdemokratiet
# 9      1  albertslund      A             Socialdemokratiet
# 10     1  albertslund      A             Socialdemokratiet
# 11     1  albertslund      A             Socialdemokratiet
# 12     1  albertslund      A             Socialdemokratiet
# 13     1  albertslund      A             Socialdemokratiet
# 14     1  albertslund      A             Socialdemokratiet
# ...
